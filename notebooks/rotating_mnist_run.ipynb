# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/My Drive/InImNet/inim_code/

# %%
# !python3 rotating_mnist.py  --task_id=1 --seed=1
# !python3 rotating_mnist.py  --task_id=2 --seed=2
# !python3 rotating_mnist.py  --task_id=3 --seed=3
# !python3 rotating_mnist.py  --task_id=4 --seed=4
# !python3 rotating_mnist.py  --task_id=5 --seed=5
# !python3 rotating_mnist.py  --task_id=6 --seed=6
# !python3 rotating_mnist.py  --task_id=7 --seed=7
# !python3 rotating_mnist.py  --task_id=8 --seed=8
# !python3 rotating_mnist.py  --task_id=9 --seed=9
# !python3 rotating_mnist.py  --task_id=10 --seed=10
